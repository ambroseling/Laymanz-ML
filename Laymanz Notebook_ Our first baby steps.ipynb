# %% [markdown]
# # Laymanz Notebooks: Fundamentals
# Author: Ali Ahmad & Amrbose Ling
#
# **Our goal is to get rid of abstractions and black boxes when learning about ML**
#
# **What is this notebook about?**
#
# In this notebook, we will go over some of the most common fundamental mathematical concepts used in Machine Learning, more specifically Deep Learning. We want these notebooks to be dense and concise. There will be interactive examples, coding exercises and a final challenge made just for you to set you up for success in the later notebooks!
#
# **What do I need to set up my environment?**
#
# All of our notebooks will only use numpy, pytorch, matplotlib for visualizations. If you are very eager to learn about what PyTorch is and how it works, check out this super detailed notebook on PyTorch! If you are running this on colab you can just import the packages, if you are running this notebook locally , just remember to `pip install numpy torch matplotlib`. Check [here](https://pytorch.org/get-started/locally/) to see which torch version depending on the hardware you have.
#
# **How is this notebook structured?**
#
# Each notebook will have
#
# [**How to use matplotlib for plotting**](https://colab.research.google.com/github/amanchadha/aman-ai/blob/master/matplotlib.ipynb#scrollTo=1-AcMM6NSmP-)
#
#
# ## Breakdown
# *   Calculus
# *   Linear Algebra
# *   Probability & Statistics

# %%
# Lets install and import numpy and torch
import numpy as np
import torch
import matplotlib.pyplot as plt

# This is just a helper function to help us plot functions
def plot_function(x,y):
  plt.axis([-10, 10, 0, 20])
  plt.plot(x,y)
  plt.show()

# %% [markdown]
# # Calculus 🏛
#
# Calculus forms a very core foundation for Machine Learning. It allows us to study change (Change of functions over time, rates of change,derivatives, intergrals and many more). Undoubtedly there are many topics depending on the research stream or the specific application of ML or DL, we will focus on some of the most key and useful concepts that are generally applicable across all streams of ML and DL.

# %%
#1. Lets define a function
x = np.linspace(-10,10,1000)
f = lambda x: x**2
y = f(x)
plot_function(x,y)

# %%
# We can apply more transformations to the input of the function
# What if we want to model the function y = 3x^2-5x+4
x = np.linspace(-10,10,1000)
f = lambda x: 3*x**2 - 5*x +4
y = f(x)
plot_function(x,y)

# %%
# This is boring, lets do something more interesting...
# How do we find out how fast the function y = 5x^3+9x? (finding rise over run)
f = lambda x: 5*x**3 + 9*x

# Method 1: Use the derivative rules we learnt from high school (Symbolic differentiation)
dydx_sym = 15*x**2 + 9

#Uncomment to see the actual values
# print(f"dydx from derivative rules: {dydx_sym}")


# Method 2: Use first principles (Numeric differentiation)
# f'(x) = lim as h->0 f(x+h)-f(x)/h
# Lets set h to a very small number
h = 0.00000001
dydx_num = (f(x+h)-f(x))/h

#Uncomment this to see the actual values
# print(f"dydx from first principles: {dydx_num}")

#You can see that we get the same answer with both methods
np.isclose(dydx_sym,dydx_num)

#Lets visualize the derivative
plot_function(x,f(x))
plot_function(x,dydx_num)

# %% [markdown]
# ## Derivates
#
# Derivates describe the rate of change of a function, how fast or slow a function is changing with respect to some variable.

# %% [markdown]
# # Linear Algebra 👽
#
# Linear algebra deals with vectors and matrices, both of which are the "[basis](https://en.wikipedia.org/wiki/Basis_(linear_algebra))" of machine learning and deep learning. (Haha see what i did there)

# %% [markdown]
# ## Vectors
#
# **What is a vector?**
#
# Vectors are just numbers or a collection of numbers. We associate them with a *magnitude* and a *direction*. We usually think of them as coordinates in some **n** dimensional space.
#
# **Why do we use vectors?**
#
# Vectors are very useful in machine learning because it helps us represent different objects in real life. We can associate a collection of numbers to these entities.
#
# Interpretation:
# You can think of using a specific collection of numbers to represent just literally anything. For example:
#
# 1. Vectors to describe your location `Lat, Lon = (-20.00,45.89)`
# 2. Vectors to describe the RGB values of a pixel `R,G,B = (128,65,255)`
# 3. Vectors to describe words, or we call these [embedding](https://en.wikipedia.org/wiki/Word_embedding) vectors `happy = [-0.98625,2.38764,9.8366,...]`
#
#
#
#
#
# **How do vectors work?**
#
# A vector is represented by a 1-dimensional list (One set of []). A vector can store integers, or floating point numbers, many other different data types. They can also be signed or unsigned.
#
# We call a vector with *n* elements in it, a **n** dimensional vector. If I have a vector that looks like `x = [1.00,9.82,3.42]`, we call this a *3 dimensional* vector.

# %%
#Lets create a 3-d vector (this we can visualize)
a = np.array([1,1,2])
#Lets create a 3-d vector (this we can visualize)
a = np.array([1,1,2])


# What about a 8-d vector (this we can not visualize:/)
c = np.array([2,10,8,9,4,48,34,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e6312f13cc1f> in <cell line: 2>()
#       1 #Lets create a 3-d vector (this we can visualize)
# ----> 2 x = np.array([1,1,2])
#       3 # What about a 8-d vector (this we can not visualize:/)
#       4 y = np.array([2,10,8,9,4,48,34,1])
#
# NameError: name 'np' is not defined

# %% [markdown]
# **What can you do with vectors?**
# You can apply mathematical operations on vectors. We will show a few here:

# %%
# Element wise operations
# Add / Sub / Div / Mult 2 vectors together
c = a + b

c = a * b

# Scalar Multiplication
# each entry is multiplied by 1 scalar
c = 5 * a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6d64d9e43d11> in <cell line: 3>()
#       1 # Element wise operations
#       2 # Add / Sub / Div / Mult 2 vectors together
# ----> 3 z = x + y
#       4
#       5 z = x * y
#
# NameError: name 'x' is not defined

# %%
# Dot Product
# the dot product is the sum of the products of 2 entries from 2 vectors

# Example 1:
dot_product = a[0]*b[0] + a[1]*b[1] +a[2]*b[2]

# Example 2:
dot_product = 0
for i in range(len(a)):
  dot_product += a[i]*b[i]

# %% [markdown]
# ## Matrices
# To extend the idea of vectors further, we can take a collection of vectors and form these table-looking collection of numbers.
#
# **What is a matrix?**
# A $m \times n$ matrix, more formally is a 2-d array of numbers where each entry $a_{i,j}$ where $1 \le i le m$ and $1 \le i le n$
# We say a matrix is $m \times n$ if it has $m$ rows and $n$ columns
# We also call a matrix square if $m = n$
#
#
# **Why do we use matrices?**
# Matrices are useful ways to represent quantitative entities in that structure
#
# * Images as a matrix (i.e. $256 \times 256$ or in other words 256 rows and columns of pixels )
# * To solve systems of linear equations as a matrix
# * Embedding matrix for words (i.e. $100 \times 1024$ 100 token embeddings with 1024 dimension each or 100 rows of tokens and each token has a 1024 dimensional vector)
# * Weight matrices of a neural network layer
# * Kernel matrix of a convolutional layer
# * Q,K,V matrices of the attention mechanism
#
# If you never heard of any of this stuff, don't stress at all we have continuing notebooks to guide you through all of these concepts.

# %%
# Lets create a matrix
# a 2 x 2 matrix with 2 rows and 2 columns
x = np.array([[1,2],[2,3]])

# Lets create another matrix
y = np.array([[3,4],[5,6]])

# %%
# Lets do some matrix operations
# Sum of 2 matrices
z = x + y

# %%
# Negation of a matrix
neg_x = -x

# %%
# Scalar multiplication
z = 5 * x

# %%
# Transpose
# the transpose operation swaps the rows and columns of a matrix
# such that A's jth row is A^T's jth column

z = x.T

# why do we need tranpose?
# explain...

# %%
# Inverse of a matrix
# The inverse of a matrix is a matrix A^-1 such that A*A^-1 = I
x = np.linalg.inv(x)

# %%
# Special matrices

# Identity matrix
x = np.identity(3)
# This creates an identity matrix where all the diagonal entries are 1 and all other
# The identity matrix is a N x N square matrix, linearly independent and the standard basis of N

# %%
# Matrix Multiplication
#

# %% [markdown]
# **NOTE:**

# %% [markdown]
# # Probability & Statistics 🎯

# %% [markdown]
# 1. Probability Basics
# Probability Theory: The study of randomness and uncertainty. Understanding probability helps in modeling the likelihood of events happening.
# Conditional Probability: How the probability of an event changes when another related event is known to occur. This is crucial in many ML algorithms, like Naive Bayes.
# Bayes' Theorem: A way to reverse conditional probabilities that's essential in many ML contexts, such as spam filtering and disease diagnosis.
#
#
# 2. Statistical Functions
# Mean and Median: Measures of central tendency that summarize the central point of a data distribution.
# Variance and Standard Deviation: Measures of dispersion that describe the spread of data points around the mean.
# Covariance and Correlation: Indicate the relationship and dependency between two variables. Correlation coefficients are used to quantify the strength of a relationship.
#
# 3. Distributions
# Normal Distribution (Gaussian): A very common continuous distribution used in statistics because many techniques and methods are optimized to work with it.
# Binomial Distribution: Useful for modeling the number of successes in a fixed number of independent Bernoulli trials (like flipping a coin).
# Poisson Distribution: Often used for modeling the number of times an event happens in a fixed interval of time or space.
#
# 4. Hypothesis Testing
# Null and Alternative Hypotheses: Formulating and testing assumptions about a population using sample data.
# P-values and Significance Levels: Used to determine the strength of the evidence against the null hypothesis.
# Confidence Intervals: Provide a range of values that likely contain the population parameter.

# %% [markdown]
# ## Bayesian Statistics
# Bayesian statistics offers a powerful framework for machine learning (ML) by incorporating **prior knowledge, handling uncertainty explicitly, and offering probabilistic predictions.**
#
#
# Condintional probability is at the very heart of Bayesian statistics. It works by leveraging a set of observations denoted as $X$, lets assume that the observations are generated by a distribution $P$.
#
# When we say that observations are generated by a distribution $P$, it means that the data points in our "observation" are considered to be **random samples drawn from that specific probability distribution.** That probability distribution could be normal, biased, etc. Depends on the scenario.
#
# Examples:
# - If each data point in my observation represents the height of an individual adult man. Then the observations (heights) are assumed to follow a normal distribution.
# - if each data point represents the outcome of a single die roll.
# Then since the die is fair, each face (1 through 6) has an equal probability of landing face up. This situation is described by a uniform distribution.
#
# We denote the parameters of this distribution as $H$, and lets also assume we know the shape of this distribution.
#
# **Bayes rule:**
# $$
# P(H|X) = \frac{P(X|H) \cdot P(H)}{P(X)}
# $$
# where
#
#
# * $P(H|X)$: posterior distribution (based on an observation, whats the probability of )
# * $P(X|H)$: likelihood (based on some set of parameters, whats the probability of observation)
# * $P(H):$ prior distribution (distribution of parameters)
# * $P(X):$ marginalization or evidence (the probability of the observations being true)
#
# **NOTE**:
# We assume:
# * posterior has a certain shape
# * parameters are drawn from a given prior
#
# Ali Intuition:
# Posterior distribution: having a prior beleif about the scenario. Example: you are trying to see if a **coin is biased or not**, one way is by doing a lot of coin flips. Obviously, the more coin flips you do, the more certain you will be if the coin is biased or not.
#
# My question is: **How do we model this change in certainty, as we do more coin flips?**
#
# I start off by assuming the coin is not biased, so my posterior distrutibution, at 0 coin flips will be a uniform distribution, with equal likelihood of a heads or a tails. This is my Prior Belief at this point in time (0 flips).
# As I observe a heads, or a tails on a coin flip, I continue to "update" this beleif. Lets see what this "updated" prior Belief might look like:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Notice that in this scenario, the coin ended up being a fair coin. (at 500 tosses, 250 of them are heads). If it was actually biased, lets say Probability of a heads is .7, then my Prior will STILL be uniform, and would eventually get updated to being .7 for Probability of heads. Something like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The key idea here is how our prior distribution is able to model our observations at each coin flip. So it incorporates Prior Knowledge, and handles uncertainty (if we have done 1 flip and seen 1 heads, it doesn't mean the probabilty of tails is 0).
#
# Lets model this:

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import Button, VBox, Output, IntText, FloatSlider
from scipy.stats import beta
import time

# Set up the initial parameters for the Beta distribution
alpha_param, beta_param = 1, 1  # Uniform prior

# Create output widget to display the plot and text output for flip results
out_plot = Output()

# Create input field, button, and reset button
n_flips_text = IntText(value=10, description='Number of Flips:', layout={'width': '180px'})
prob_slider = FloatSlider(value=0.5, min=0, max=1, step=0.01, description='Prob Heads:', readout_format='.2f')
button_auto_flip = Button(description='Start Auto Flip', button_style='primary', layout={'width': '150px', 'height': '50px'})
button_reset = Button(description='Reset', button_style='danger', layout={'width': '100px', 'height': '50px'})

# Function to update the plot based on the coin flip
def update_plot(heads, tails):
    x = np.linspace(0, 1, 100)
    y = beta.pdf(x, 1 + heads, 1 + tails) # This is where the
    with out_plot:
        out_plot.clear_output(wait=True)
        plt.figure(figsize=(10, 5))
        plt.plot(x, y, label=f'Heads: {heads}, Tails: {tails}')
        plt.fill_between(x, 0, y, color="#348ABD", alpha=0.4)
        plt.title("Bayesian updating of posterior probabilities")
        plt.xlabel("$p$, probability of heads")
        plt.ylabel("Density")
        plt.legend()
        plt.show()

# Handlers for automatic flipping and reset
heads_count = 0
tails_count = 0

def on_auto_flip_clicked(b):
    global heads_count, tails_count
    n_flips = n_flips_text.value
    for _ in range(n_flips):
        if np.random.rand() < prob_slider.value:
            heads_count += 1
        else:
            tails_count += 1
        update_plot(heads_count, tails_count)
        time.sleep(0.5)  # Pause for half a second between flips for visibility

def on_reset_clicked(b):
    global heads_count, tails_count
    heads_count = 0
    tails_count = 0
    update_plot(heads_count, tails_count)

# Attach the button click events to their respective handlers
button_auto_flip.on_click(on_auto_flip_clicked)
button_reset.on_click(on_reset_clicked)

# Display the widgets and output
display(VBox([n_flips_text, prob_slider, button_auto_flip, button_reset]), out_plot)

# Initial plot
update_plot(heads_count, tails_count)
# Out:
# ...
# Output()
