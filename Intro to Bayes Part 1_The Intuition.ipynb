# %% [markdown]
# In this Notebook, Our goal is to:
#
# - Know some brief history of Bayesian Statistics
# - Understand What Bayesian Statistics is, and why it matters today
# - Know what Frequintist Vs Bayesian Prespective
# - understand What Prior, Posterior, Likelihood and Normalizing Constant is.
#
# All of these will be explained by the use of intuitive examples

# %% [markdown]
# ## Brief history of Bayesian Statistics

# %% [markdown]
# Bayesian statistics is named after Thomas Bayes, an 18th-century mathematician, who developed the initial ideas of [probability inversion.](https://chatgpt.com/share/6fe67326-0a0b-4ef6-8f25-f6d60a21e62b)
#
# Bayes' Theorem, published after the death of Thomas in 1763, provided the foundation for Bayesian inference. So he never actually got to see his work, and the true potential it had.
#
#
# The 20th century worked towards the more formal Bayesian methods, with significant contributions from statisticians like Pierre-Simon Laplace, who generalized Bayes' ideas and applied them to various scientific fields.

# %% [markdown]
# ## What is Bayesian Statistics?

# %% [markdown]
# Bayesian Statistics expresses a degree of belief in an event. This belief may change as new evidence is presented. The Bayesian approach uses Bayes' Theorem to update the probability of a hypothesis as more data or information becomes available.
#
# In short, Bayesian statistics combines prior knowledge with new evidence to form updated, more accurate predictions with the present data.

# %% [markdown]
# ## Why Bayesian Statistics Matter in Modern Data Science:

# %% [markdown]
# <a name="Pros"></a>
# Pros:
# - **Incorporation of Prior Information:** Bayesian methods allow the integration of prior knowledge (such as historical data, and expert opinion, results from past research, [etc](https://chatgpt.com/share/8846e551-1374-4437-83e4-43ff9ee45064)) into the analysis, making them powerful in fields such as Healthcare, Finance, ML and Robotics to name a few.
# - **Flexibility:** They can effectively model complex relationships (linear, non-linear etc) and [nested data structures](https://chatgpt.com/c/604e1d2b-df8a-476f-9011-351b243e5a26), which makes them powerful tools for analyzing more complicated real-world data problems in fields like recommendations systems, weather forecasting, and medical diagnosis.

# %% [markdown]
# ## The 2 Prespectives: Red Pill and Blue Pill

# %% [markdown]
# This video explains it beautifully: [Video](https://www.youtube.com/watch?v=BcvLAw-JRss)

# %% [markdown]
# ### The Blue Pill: Frequentist Prespective 🟦

# %% [markdown]
# **Core Idea: **It interprets probability as the long-run frequency of events,
#
# **ex:** if we observing Probability of a black car crossing an intersection, we would do: $\frac{\text{Number of times you see a black car cross intersection}}{\text{Total number of cars that crossed the intersection}}$
#
#
# This means, that the probability of an event, is seen as:
# $\lim_{n -> ∞} \frac{\text{Frequency of Black Cars}}{\text{Total numbers of Cars}}$, where $n$ is the number of trials / cars we observed.

# %% [markdown]
# **Conclusion:** Main drawback is that if you don't observe something, lets say a rare color like candy red with gold flakes,your Frequentist model will say the probability of such a color existing is 0, because it may never observe it. This is inaccurate as it can lead to incorrect results in many modeling scenarios.

# %% [markdown]
# ### The Red Pill: Bayesian Prespective 🟥

# %% [markdown]
# **Core idea:** Uses probabilities to represent confidence in a certain hypothesis/belief. It does this by incorporating prior knowledge (prior distribution) along with the data (likelihood) to form a posterior distribution. (we will expand on these in detail a couple sections.)
#
# Pros:
# Same as the ones here: [Pros:](#Pros)
#
# Cons:
# - **Subjectivity**: The choice of prior can be subjective and can influence the results, especially with limited data. Imagine choosing the wrong source of information, making your probability distribution biased/skewed.
# - **Complexity**: Can be harder to understand and communicate, particularly to those unfamiliar with Bayesian methods. **AND Thats why we are learning it right now!**
#
# PS: Bayesian Prespective is objectively just better, so always say you are Baysian when asked

# %% [markdown]
# Before we dig deeper into Bayes Theorum, lets look at Conditional Probability, which is a core part of Bayes Statistics.

# %% [markdown]
# ## Conditional Probability, full intuition

# %% [markdown]
# This is an excerpt from thinkBayes by Allen B. Downey, page #1. He explains it in a very very nice way so I'm gonna let him cook:
#
# A conditional probability is a probability based on some background information.
#
# For example, I want to know the probability that I will have a heart attack in the next year. According to the CDC, "Every year about 785,000 Americans
# have a Heart attack-[(source)](http://www.cdc.gov/heartdisease/facts.htm).
# The U.S. population is about 311 million, so the probability that a randomly
# chosen American will have a heart attack in the next year is roughly 0.3%.
# But I am not a randomly chosen American. Epidemiologists have identified
# many factors that affect the risk of heart attacks; depending on those factors,
# my risk might be higher or lower than average.
#
# I am male, 45 years old, and I have borderline high cholesterol. Those factors
# increase my chances. However, I have low blood pressure and I don't smoke,
# and those factors decrease my chances.
# Plugging everything into the [online calculator](http://cvdrisk.nhlbi.nih.gov/calculator.asp), I find that my risk of a heart attack in the next
# year is about 0.2%, less than the national average. That value is a conditional
# probability, because it is based on a number of factors that make up my
# "**condition**."

# %% [markdown]
# So here, if we are to write this formally, the usual notation for conditional probability is $p(A|B)$, which is the probability
# of $A$ given that $B$ is true. In this example, $A$ represents the prediction
# that I will have a heart attack in the next year, and $B$ is the set of conditions
# I listed.

# %% [markdown]
# ### The difference between Bayes and Conditional Probability:
#
#
# Conditional Probability refers to the probability of an event occurring given that another event has already occurred.
# The formula is simply:
# $$P(A|B) = \frac{P(A \text{ and } B)}{P(B)}$$
#
# While Bayes theorum is a way of finding a probability when other related probabilities are known (like likelihood, Posterior etc).
# And the formula, is a tweaked version of Conditional Probability:
# $$P(A|B) = \frac{P(A) *P(B|A)}{P(B)}$$

# %% [markdown]
# ## Bayes Theorum

# %% [markdown]
# Before we dig into what exactly Bayes Theorum is, Its helpful to watch this video, to get some intuition behind its workings:
# https://www.youtube.com/watch?v=U_85TaXbeIo

# %% [markdown]
# These are the core parts of the Bayes theorum, and their formal defenitions. We will dig deeper into each of them, as we learn about Bayes using the following series of Examples, that build upon each other, and explore Bayes from different perspectives.
#
# Source: thinkBayes by Allen B. Downey, page #5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1: Explaining what a Prior is

# %% [markdown]
# In simple words, a prior is your initial belief or estimate about a "parameter" **before you see new data**.
#
# It represents what you think you know about the parameter based on previous obervations/data, knowledge, experience, and/or assumptions. The **parameter** in most cases is simply the probability of an event, given some other new observed data.
#
# Biased coin example:
#
# Imagine you have a coin, and you want to know the probability that it lands heads (let's call this probability $θ$).
#
# **Before Flipping the Coin:**
#
# Suppose you have no reason to believe the coin is biased, so you might initially believe that heads and tails are equally likely.
# This belief can be represented as a prior distribution where $θ$ is equally likely to be any value between 0 and 1, but you might center your belief around 0.5 (since you believe the coin is fair).
#
# **After Flipping the Coin:**
#
# You start flipping the coin and observe the outcomes. Based on these outcomes, you update your belief about $θ$. This updated belief, which combines your prior with the new data, is called the posterior distribution.
#
# Lets look at some coded examples:

# %% [markdown]
# This is our coin that looks pretty fair:
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Yes he did say that in the same sentence

# %% [markdown]
# However, we have our doubts, because a dimentia patient near where you live, Joe, keeps telling you that he looses his bets everytime he doesn't bet on Donald Trump (so tails).
# He says that the coin must be biased because 7 out of 10 times, the coin landed heads. Lets see if this makes this coin biased or not:

# %% [markdown]
# We believe, because Joe said, that the coin is biased. So our Prior (initial belief) is that the coin is biased. Now, we can represent this belief like so:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here, we can see that we are most confident that "$θ$" is 0.7, as demonstrated by having higher probability density. And less confident, in other values such as 0.5. We can see, that this is a result, after flipping the coin for 10 times, which is what Joe told us.

# %% [markdown]
# This is Prior Distribution/Belief. It represents our confidence in value of .7 being the most likely value of the coin's probability of landing on heads.

# %% [markdown]
# ## 2: Explaining what a Posterior is

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A Posterior Distribution, is simply our new belief in a certain hypothesis being true, after observing a certain outcome. For example lets look at this diagram:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is the relationship between Prior and Posterior, and how are they interchangeable, as we do the next iterations?**
#
# The Posterior Distribution from the first result, acts as a Prior Distribution for the next iteration. It informs our belief for the next flip, with the observed data. So as we do another iteration, the previous iteration's Posterior, becomes the current iteration's Prior.

# %% [markdown]
# Hopefully, we can see how $P(H|D)$ is true, as: $P(\text{Our hypothesis of θ being a certain value } | \text{ given the data we have observed so far})$

# %% [markdown]
# ## 3: Explaining what Likelihood is.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Likelihood is not the same thing as probability. It does not have to add up to 1.
#
# I like to think of Likelihood, as us trying to best Estimate, what the UNDERLYING distribution, from which the data came from, looks like.
#
#
# We use it, when we OBSERVE the data, and want to know, whats the probability that the DISTRIBUTION the data came from, was with a certain parameter. Lets discuss this futher:
#
# Lets say you flip this coin twice, without knowing if it is biased or not.
#
# if you see that it landed 2 times on heads,
# - whats the probability of this happening, if the **coin was fair**? $P(2\text{ heads} |\text{ probability of heads} = .5)$ = it is: $.5*.5$ = $.25$. Therefore, the likelihood of obsreving 2 heads, if the coin is fair is $.25$
# - whats the probability of this happening, if the coin was NOT fair, and was in reality biased towards heads by .7?:
#
#  Well then the Likelihood of this happening would be: $P(2\text{ heads} |\text{ probability of heads} = .7)$ = it is: $.7*.7$ = $.49$.
#
# This "probability" is actually the likelihood, of observing specific results, under the assumption that the coin is either biased (with a certain $θ$ value, or not.
#
# Hopefully its easier to see how we have the formula of $P(D|H)$ as:
# $P(\text{Data/results we wish to see }|\text{ given a certain hypothesis (AKA a fixed value for θ)})$

# %% [markdown]
# ### Another Visual Example:

# %% [markdown]
# Source: [StatQuest Goated Vids](https://www.youtube.com/watch?v=XepXtl9YKwc)

# %% [markdown]
# Imagine you see this data on mouse weights:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What distribution do you think this data came from out of these three:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From the data, we can see that it is more concetrated towards the middle, and less concentrated as we go further away, so the LIKELIHOOD of the distribution the data came from, is mostly likely to be Normal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4: Explaining what "Normalizing Constant" means

# %% [markdown]
# For this, we can come back to Conditional Probability, and why we have to normalize in the first place.
#
# When we are calculating probability, GIVEN some other fact, we have to account for that right.
#
# For example:

# %% [markdown]
# Example: Suppose you have 100 students:
#
# - 20 of them study more than 10 hours a week.
# - 5 of those who study more than 10 hours get an A.
#
# Therefore, P(A and B) = 5/100 = 0.05 (5%).
# P(B) = 20/100 = 0.20 (20%).
#
# If I ask you now, calculate how many students will get an A, OUT of the 20 students who study more then 10 hours.
# Thinking about it logically, we know that out of the 20 students, 5 get an A, so the probability must be: $\frac{5}{20}$
# This evaluates to the expression:

# %% [markdown]
# $$P(\text{get an A | Study more then 10 hours}) = \frac{P(A \text{ and } B)}{P(B)}$$
# Which gives us $\frac{0.05}{0.20}$ = .25.
# Hence, by normalizing,
# - we are accounting for the fact that we have reduced our Sample space of probabilities we are looking at.
# - And we ensure the probabilities add up to 1.
